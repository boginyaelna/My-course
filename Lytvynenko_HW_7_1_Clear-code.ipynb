# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):
    """Виводить привітання для переданого імені.""" 
    print(f"Hello, {name}")


def add(n1, n2):
    """Повертає суму двох чисел."""
    return n1 + n2
    

x = 5
y = 3
display(greet("John"), add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
- перенесла рядок у функції після : на новий
- додала відповідний відступ після першого рядка функції
- додала два порожні рядки між визначеннями функцій
- додала пробіл в аргументах функції після коми
- огорнула пробілами + 
- додала два порожні рядки перед оголошенням змінних 
- зробіла кожну перемінну з нового рядка
- прібрала непотрібний знак ;
- у display поставіла пробіл після комі
- у функції greet замість  print зробила return щоб уникнути виводу None значення адже в початковій версії функція greet нічого не повертає
- Додано докстроки ("""опис функції""") для пояснення роботи функції

# %% [markdown]
# Завдання 2.

# %%
from math import *


def calc_area(r):
    """Обчислює площу кола за заданим радіусом."""
    return pi * r ** 2


def calc_сircumference(r):
    """Обчислює довжину кола за заданим радіусом."""
    return 2 * pi * r
    

radius = 5
print("Area:", calc_area(radius), "Circumference:", calc_сircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
- з модуля math імпортуала ліше потрібну змінну і взагалі конструкція from math import * майже заборонена 
- додано два порожні рядкі між імпортом та визначенням функції
- перейменування обох функцій відповідно  PEP8
- перенесла рядок у функції після : на новий
- додала відповідний відступ після першого рядка функції
- додала пробіли навколо операторів * та ** (як варіант замість ** можна імпотрувати ще з модуля math функцію pow()
і викоритстати її для піднесення до квадрату)
- додала два порожні рядки між визначеннями функцій
- дадала пробіли навколо = 
- додала докстроки ("""опис функції""") для пояснення 
- додала порожні рядки перед оголошенням змінних
- додада пробіли після ком у принті

# %% [markdown]
# Завдання 3.

# %%
class Animal:
    pass


class Dog(Animal):
    def __init__(self, name):
        self.name = name
        self.type = 'Dog'

# %%
- перейменування обох класів відповідно  PEP8
- перенесла рядок у класі після : на новий
- додала відповідний відступ після першого рядка визначення класу 
- додала два порожні рядкі між класами 
- при наслідуванні класу віправила імя наслідуваного класу
- в конструкторі класу в переліку атрібутів поставила пробіл після коми
- дадала пробіли навколо =

# %% [markdown]
# Завдання 4.

# %%
numbers_list = [1, 2, 3, 4, 5]


for i in range(len(numbers_list)):
    print(numbers_list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
- перейменувала list на numbers_list, адже list це вбудованій тип і його не можна використовувати для оголошення змінних 
- дадала пробіли навколо = 
- елементи спіску розділили пробілами після коми
- додала два порожні рядки перед циклом
- перенесла рядок у циклу після : на новий
- додала відповідний відступ після першого рядка визначення циклу

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages
df['average_score']
# Out:
# 0    88.333333
# 1    91.333333
# 2    79.000000
# 3    86.333333
# Name: average_score, dtype: float64

# %%
# Вікорісталі стандартну функцію Pandas .mean() для обчислення середнього значення, axis=1 - рахуваті середнє по рядках
df['average_score'] = df[['math_score', 'english_score', 'history_score']].mean(axis=1)
df['average_score']
# Out:
# 0    88.333333
# 1    91.333333
# 2    79.000000
# 3    86.333333
# Name: average_score, dtype: float64

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

# Вимірюємо використання пам'яті до оптимізації
memory_before = df.memory_usage(index=False).sum()

# # Перетворюємо стовпців «product_name» і «product_category» текстові стовпці на категоріальні
for col in ['product_name', 'product_category']:
    df[col] = pd.Categorical(df[col])

# Вимірюємо використання пам'яті після оптимізації
memory_after = df.memory_usage(index=False).sum()

# Обчислюємо економію пам’яті
reduction_ratio = round(memory_before / memory_after, 2)

# %%
print(f"Використання пам'яті ДО: {memory_before / 1024**2:.2f} MB")
print(f"Використання пам'яті ПІСЛЯ: {memory_after / 1024**2:.2f} MB")
print(f"Оптимізований DataFrame займає у {reduction_ratio} разів менше пам’яті!")
# Out:
# Використання пам'яті ДО: 30.52 MB
# Використання пам'яті ПІСЛЯ: 17.17 MB
# Оптимізований DataFrame займає у 1.78 разів менше пам’яті!

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
# 7.1 - завантаження данних
df = pd.read_csv('ecommerce_data.csv', encoding='ISO-8859-1')
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom

# %%
# Заповнюємо пропущені значення і перетворюємо на str (по логіці речей ID не може бути такого вігляду - 17850.0,
# тому робимо деякі додоткові маніпуляції)
df['CustomerID'] = df['CustomerID'].fillna(-1).astype(str).str.replace('.0', '', regex=False)
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom

# %%
! pip install sweetviz

# %%
# Вимикаємо опередженя (Warning) і запускаємо sweetviz
import sweetviz as sv
import warnings

with warnings.catch_warnings(record=True):
    compare_report = sv.compare(
        [df[df['Country'] == 'Germany'], "DF_Germany"],
        [df[df['Country'] == 'France'], "DF_France"])
    compare_report.show_html('Germany_France_compare_report.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Germany_France_compare_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
5 відмінностей:
- в Німеччіні більше унікальніх замовлень як в кількісному так і в процентному відношенні
- максимальна кількість товарів в одному замовленні у Франції – 912, а в Німеччині – 600
- середня та медіанна ціна товару практично однакова у Франції та Німеччині, це означає однакову цінову політику для обох країн
- у Німеччині більше унікальних InvoiceNo (603, 6%), ніж у Франції (461, 5%), що свідчіть про більшу різноманітність покупок у Німеччині,
у той час як у Франції, ймовірно, більше повторюваних замовлень.
- Обидві країни мають подібні часові діапазони здійснення замовлень, але у Франції помітно більше сплесків у певні дні,
можливо у Франції є певні дні або години, коли покупки значно активізуються, наприклад, у вихідні або в період акцій.

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %% [markdown]
# Чи є і які помилки в наступному коді

# %% [markdown]
# ![Снимок экрана 2025-02-19 в 08.29.30.png](attachment:4d15248a-23a0-4f3c-8136-35ed3eee5a34.png)

# %% [markdown]
# ![Снимок экрана 2025-02-19 в 08.29.51.png](attachment:01805515-9c14-4ddb-b80e-bfa424282d40.png)

# %% [markdown]
# Перепиши цей код із повним дотриманням стандарту PEP8. Відповідь стисло дай код та що саме ти зробив по пунктам.
#
# def calculate_variance(nl):
#     sum_list = sum(nl)  # Сума елементів списку
#     mean = sum_list / len(nl)  # Середнє значення
#
#     sum_squares = sum(n**2 for n in nl)  # Сума квадратів
#     mean_squares = sum_squares / len(nl)  # Середнє значення квадратів
#
#     variance = mean_squares - mean**2  # Формула дисперсії
#     return variance

# %% [markdown]
# ![Снимок экрана 2025-02-19 в 08.36.22.png](attachment:a41a7bbb-14ff-47fc-8ced-99e595338655.png)

# %% [markdown]
# ![Снимок экрана 2025-02-19 в 08.36.29.png](attachment:79dff0b9-67e1-4acd-8753-ff858b46fb2f.png)

# %% [markdown]
# Ану подивися уважненько ще раз у ПЕП-8 і згадай, що всі математичні оператори обертаються пробілами, але в тебе ні в одному із кодів немає цих пробілів. Ось що я мала на увазі.

# %% [markdown]
# ![Снимок экрана 2025-02-19 в 08.41.36.png](attachment:41b8088b-8e5d-4352-afbe-cfe259cbe6d5.png)

# %%
def calculate_variance(num_list):
    """
    Обчислює дисперсію списку чисел.

    Параметри:
    num_list (list): Список чисел.

    Повертає:
    float: Дисперсія списку.
    """
    total_sum = sum(num_list)
    mean_value = total_sum / len(num_list)

    sum_of_squares = sum(n ** 2 for n in num_list)
    mean_of_squares = sum_of_squares / len(num_list)

    variance_value = mean_of_squares - mean_value ** 2
    return variance_value

# %%
input_list = [75, 80, 85, 90, 95]
print(calculate_variance(input_list))
# Out:
# 50.0

# %% [markdown]
# Я використовую чат GPT часто в навчальних цілях і мій найбільший висновок - чім чіткіший та конкретніший промт напишеш, тим кращу і правдивішу відповідь отримаєш
